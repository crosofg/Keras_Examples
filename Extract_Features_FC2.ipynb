# %%
from keras.applications.vgg19 import VGG19
from keras.preprocessing import image
from keras.applications.vgg19 import preprocess_input
from keras.models import Model
import numpy as np
from keras.utils.visualize_util import plot
from IPython.display import SVG
# Out:
# Using TensorFlow backend.

# %%
base_model = VGG19(weights='imagenet')
# Out:
# /usr/local/lib/python2.7/dist-packages/keras/applications/vgg19.py:131: UserWarning: You are using the TensorFlow backend, yet you are using the Theano image dimension ordering convention (`image_dim_ordering="th"`). For best performance, set `image_dim_ordering="tf"` in your Keras config at ~/.keras/keras.json.
#   warnings.warn('You are using the TensorFlow backend, yet you '

# %%
from keras.utils.visualize_util import model_to_dot

# %%
SVG(model_to_dot(base_model).create(prog='dot', format='svg'))

# %%
model = Model(input=base_model.input, output=base_model.get_layer('fc2').output)

# %%
SVG(model_to_dot(model).create(prog='dot', format='svg'))

# %%
img_path = 'elephant.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
fc2_features = model.predict(x)

# %%
fc2_features
# Out:
# array([[ 0.        ,  0.23735754,  4.02377844, ...,  0.        ,
#          1.77738905,  0.        ]], dtype=float32)

# %%
type(fc2_features)
# Out:
# numpy.ndarray

# %%
fc2_features.shape
# Out:
# (1, 4096)
